# %%
import mysql.connector
import json, os
import pandas as pd
from semrep import get_oneof_type
from semrep import filter_relations

# %% [markdown]
# # Extraction relations from Semrep output

# %% [markdown]
# ## Specify mapping to parse lines from Semrep text.out

# %%
mappings = {
        "path": 1,
        "text": {
            "sent_id": 4,
            "sent_text": 6
        },
        "entity": {
            'cuid': 6,
            'label': 7,
            'sem_types': 8,
            'score': 15
        },
        "relation": {
            'subject_cui': 8,
            'subject_label': 9,
            'subject_sem_types': 10,
            'subject_sem_type': 11,
            'subject_score': 18,
            'predicate_type': 21,
            'predicate': 22,
            'negation': 23,
            'object_cui': 28,
            'object_label': 29,
            'object_sem_types': 30,
            'object_sem_type': 31,
            'object_score': 38,
        }
    }

# %% [markdown]
# ## Parse lines in relations and get all extracted relations in file

# %%
text_out = "output_relations/custom_license_pdf/text.out"

# %%
extraction = {}

file = open(text_out,encoding='utf-8')
for line in file:
    results = {'relations': []}
    # If Sentence
    if line.startswith('SE'):
        elements = line.split('|')
        path = elements[1]
        if elements[5] == 'relation':
            tmp = {}
            for key, ind in mappings['relation'].items():
                if 'sem_types' in key:
                    tmp[key] = elements[ind].split(',')
                else:
                    
                    tmp[key] = elements[ind]
            results['relations'].append(tmp)
            extraction[path] = extraction.get(path, []) + results['relations']
file.close()

# %% [markdown]
# ## Output

# %%
with open("output_relations/custom_license_pdf/extraction.json",'w') as file:
    file.write(json.dumps(extraction, indent=4))

# %% [markdown]
# # Filter relations

# %% [markdown]
# ## read all relations and form triple of relations

# %%
input_file = "output_relations/custom_license_pdf/extraction.json"

# %%
all_relations = []
with open(input_file) as file:
    doc = json.loads(file.read())
    for key, value in doc.items():
        # form quadruple of relations
        tuple_relations = [(relation["subject_cui"], relation["predicate"].upper(), relation["object_cui"])\
                        if relation['negation']=='' else (relation["subject_cui"], 'NEG_'+relation["predicate"].upper(), relation["object_cui"]) \
                        for relation in value ]

            
        all_relations.append({"path":key, "relations":tuple_relations})

# %% [markdown]
# ## filter relations
#
# Only get relations that connect entities from one of the entity types ['T047', 'T028', 'T121', 'T103', 'T184'], that is [Disease, Gene, PharmaSub, Chemical, Symptom]

# %%
# initialize mysql connector


cnx = mysql.connector.connect(user='root', password='12345678',
                              host='127.0.0.1',
                              database='umls')
cursor = cnx.cursor()

filtered_relations = []
for relation in all_relations:
    filtered_relation = filter_relations(cursor, relation["relations"])
    filtered_relations.append({"path":relation["path"],"relations":filtered_relation})

cursor.close()
cnx.close()

# %% [markdown]
# ## Output to file

# %%
output_filtered_relations = "output_relations/filtered_semrep_relations/custom_license_pdf.json"

# %%
with open(output_filtered_relations, 'w') as file:
    file.write(json.dumps(filtered_relations, indent=4))

# %% [markdown]
# # Solidate relations from various sources

# %% [markdown]
# ## read .json files from given folder to solidate

# %%
input_folder = "output_relations/filtered_semrep_relations"

# %% [markdown]
# ## solidate all relations

# %%
paths = os.listdir(input_folder)

relations = set()

for path in paths:
    if path.endswith('.json'):
        with open(os.path.join(input_folder, path), encoding='utf-8') as file:
            rela = json.loads(file.read())
            for path in rela:
                relation = path['relations']
                for r in relation:
                    relations.add((r[0],r[1],r[2]))

# %%
df = pd.DataFrame(list(relations), columns=['subject','predicate','object'])

# %% [markdown]
# # Append semantic type to CUI

# %%
type_name = {'T047':'Disease', 'T028':'Gene', 
             'T121':'PharmaSub', 'T103':'Chemical', 'T184':'Symptom'}
entity_types = set(['T047', 'T028', 'T121', 'T103', 'T184'])

# %%
# initialize mysql connector
import mysql.connector

cnx = mysql.connector.connect(user='root', password='12345678',
                              host='127.0.0.1',
                              database='umls')
cursor = cnx.cursor()

# %%
def append_type_name(cui):
    tuis = get_oneof_type(cursor, cui, entity_types)
    assert len(tuis) == 1
    tui = tuis.pop()
    return type_name[tui] + "_" + cui

# %%
df['subject'] = df['subject'].apply(append_type_name)
df['object'] = df['object'].apply(append_type_name)

# %%
cursor.close()
cnx.close()

# %% [markdown]
# ## output to file

# %%
df.to_csv("output_relations/semrep_rela.csv",index=False)

# %%
df
# Out:
#                    subject           predicate              object
# 0         Disease_C0037278              CAUSES    Disease_C0012634
# 1         Disease_C0023518       COEXISTS_WITH    Disease_C0004626
# 2       PharmaSub_C1827106            DISRUPTS    Disease_C0022660
# 3            Gene_C1540289      INTERACTS_WITH       Gene_C1423633
# 4       PharmaSub_C0026698              TREATS    Symptom_C0231218
# 5         Disease_C0014038                 ISA    Symptom_C0037088
# 6         Symptom_C1457887       COEXISTS_WITH    Disease_C1175175
# 7         Disease_C0014059              CAUSES    Disease_C0338474
# 8       PharmaSub_C0250480              TREATS    Disease_C0010674
# 9         Disease_C0022680              CAUSES    Disease_C0035078
# 10        Disease_C0728936                 ISA    Symptom_C0221423
# 11      PharmaSub_C0033308              CAUSES    Disease_C0020452
# 12      PharmaSub_C0071972       COEXISTS_WITH  PharmaSub_C0008809
# 13      PharmaSub_C0003241         PREDISPOSES    Disease_C0042769
# 14        Symptom_C0019079     ASSOCIATED_WITH    Disease_C0032310
# 15        Disease_C0268382       COEXISTS_WITH    Disease_C0027726
# 16           Gene_C0079941      INTERACTS_WITH  PharmaSub_C0030956
# 17           Gene_C1420214  NEG_INTERACTS_WITH  PharmaSub_C0360105
# 18      PharmaSub_C0006220                 ISA  PharmaSub_C0026698
# 19        Disease_C0032310       COEXISTS_WITH    Symptom_C0015967
# 20      PharmaSub_C0042212            PREVENTS    Disease_C0021400
# 21        Disease_C0042769              CAUSES    Disease_C0275518
# 22      PharmaSub_C4053575      INTERACTS_WITH       Gene_C1421391
# 23      PharmaSub_C0005330                 ISA  PharmaSub_C0003392
# 24      PharmaSub_C0085231      INTERACTS_WITH  PharmaSub_C0033607
# 25      PharmaSub_C2605855                 ISA  PharmaSub_C0013227
# 26           Gene_C1424853          STIMULATES       Gene_C1425825
# 27      PharmaSub_C0093999                 ISA  PharmaSub_C1254351
# 28        Disease_C4317046       COEXISTS_WITH    Disease_C1175175
# 29        Disease_C0014335              CAUSES    Disease_C0017160
# ...                    ...                 ...                 ...
# 109575  PharmaSub_C0877869                 ISA  PharmaSub_C0003392
# 109576       Gene_C1334043     ASSOCIATED_WITH    Disease_C0002395
# 109577    Disease_C0011849                 ISA    Disease_C0014130
# 109578       Gene_C1418813            PRODUCES       Gene_C3537219
# 109579  PharmaSub_C0297666      INTERACTS_WITH  PharmaSub_C0012403
# 109580  PharmaSub_C0002615      INTERACTS_WITH       Gene_C1883559
# 109581    Disease_C0275518              CAUSES    Disease_C0036690
# 109582       Gene_C3273837      INTERACTS_WITH       Gene_C1538660
# 109583       Gene_C1335874      INTERACTS_WITH       Gene_C1708427
# 109584       Gene_C1333343            DISRUPTS    Disease_C0276500
# 109585       Gene_C1413953              CAUSES    Disease_C3150658
# 109586       Gene_C1955992         HIGHER_THAN       Gene_C0085238
# 109587  PharmaSub_C0085149      INTERACTS_WITH  PharmaSub_C0718566
# 109588  PharmaSub_C0772024       COEXISTS_WITH  PharmaSub_C0001962
# 109589  PharmaSub_C0005575       COEXISTS_WITH  PharmaSub_C0003241
# 109590  PharmaSub_C1142717         HIGHER_THAN  PharmaSub_C0063041
# 109591    Symptom_C0015967     ASSOCIATED_WITH    Disease_C1257753
# 109592       Gene_C0017337            INHIBITS       Gene_C1415892
# 109593  PharmaSub_C0597641              TREATS    Disease_C0009450
# 109594    Disease_C0001403                 ISA    Disease_C0405580
# 109595  PharmaSub_C0042210              TREATS    Disease_C1290807
# 109596  PharmaSub_C1120110            INHIBITS  PharmaSub_C0003009
# 109597  PharmaSub_C0021918             AFFECTS    Disease_C1998028
# 109598       Gene_C1424509       COMPARED_WITH       Gene_C1540067
# 109599    Disease_C0041234                 ISA    Disease_C0033740
# 109600    Disease_C0010340            PRECEDES    Disease_C0035222
# 109601  PharmaSub_C0082607            INHIBITS       Gene_C1334126
# 109602    Disease_C0272229                 ISA    Disease_C0039082
# 109603    Disease_C0024312              CAUSES    Disease_C1175175
# 109604  PharmaSub_C0040613                 ISA  PharmaSub_C0013227
#
# [109605 rows x 3 columns]
